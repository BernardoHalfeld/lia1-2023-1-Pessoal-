# %% [markdown]
# <a href="https://colab.research.google.com/github/BernardoHalfeld/lia1-2023-1-Pessoal-/blob/main/GettingStarted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Activity 2: Getting Started (fast.ai)**
#
# Student: [Bernardo Halfeld](https://github.com/BernardoHalfeld) - 202004705

# %% [markdown]
# ###  1) ------ *Is it a bird?* ------
#
# #### **Fastbook library installation**

# %%
pip install fastbook
# Out:
# Requirement already satisfied: fastbook in c:\users\nebia\anaconda3\lib\site-packages (0.0.29)
# Requirement already satisfied: graphviz in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (0.20.1)
# Requirement already satisfied: sentencepiece in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (0.1.99)
# Requirement already satisfied: packaging in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (22.0)
# Requirement already satisfied: ipywidgets<8 in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (7.6.5)
# Requirement already satisfied: fastai>=2.6 in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (2.7.12)
# Requirement already satisfied: datasets in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (2.12.0)
# Requirement already satisfied: requests in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (2.28.1)
# Requirement already satisfied: pandas in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (1.5.3)
# Requirement already satisfied: transformers in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (4.24.0)
# Requirement already satisfied: pip in c:\users\nebia\anaconda3\lib\site-packages (from fastbook) (22.3.1)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (1.5.29)
# Requirement already satisfied: matplotlib in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (3.7.0)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (1.0.3)
# Requirement already satisfied: pyyaml in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (6.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (0.0.7)
# Requirement already satisfied: torch<2.1,>=1.7 in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (2.0.0)
# Requirement already satisfied: spacy<4 in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (3.5.2)
# Requirement already satisfied: pillow>6.0.0 in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (9.4.0)
# Requirement already satisfied: scipy in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (1.10.0)
# Requirement already satisfied: torchvision>=0.8.2 in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (0.15.1)
# Requirement already satisfied: scikit-learn in c:\users\nebia\anaconda3\lib\site-packages (from fastai>=2.6->fastbook) (1.2.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\nebia\anaconda3\lib\site-packages (from ipywidgets<8->fastbook) (8.10.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\nebia\anaconda3\lib\site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\nebia\anaconda3\lib\site-packages (from ipywidgets<8->fastbook) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\nebia\anaconda3\lib\site-packages (from ipywidgets<8->fastbook) (5.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\nebia\anaconda3\lib\site-packages (from ipywidgets<8->fastbook) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\nebia\anaconda3\lib\site-packages (from ipywidgets<8->fastbook) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\nebia\anaconda3\lib\site-packages (from ipywidgets<8->fastbook) (5.7.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (1.23.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (0.14.1)
# Requirement already satisfied: responses<0.19 in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (12.0.0)
# Requirement already satisfied: multiprocess in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (2022.11.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (0.3.6)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (4.64.1)
# Requirement already satisfied: xxhash in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (3.2.0)
# Requirement already satisfied: aiohttp in c:\users\nebia\anaconda3\lib\site-packages (from datasets->fastbook) (3.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nebia\anaconda3\lib\site-packages (from requests->fastbook) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nebia\anaconda3\lib\site-packages (from requests->fastbook) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nebia\anaconda3\lib\site-packages (from requests->fastbook) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nebia\anaconda3\lib\site-packages (from requests->fastbook) (2.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nebia\anaconda3\lib\site-packages (from pandas->fastbook) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nebia\anaconda3\lib\site-packages (from pandas->fastbook) (2.8.2)
# Requirement already satisfied: filelock in c:\users\nebia\anaconda3\lib\site-packages (from transformers->fastbook) (3.9.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\nebia\anaconda3\lib\site-packages (from transformers->fastbook) (0.11.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nebia\anaconda3\lib\site-packages (from transformers->fastbook) (2022.7.9)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nebia\anaconda3\lib\site-packages (from aiohttp->datasets->fastbook) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nebia\anaconda3\lib\site-packages (from aiohttp->datasets->fastbook) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nebia\anaconda3\lib\site-packages (from aiohttp->datasets->fastbook) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nebia\anaconda3\lib\site-packages (from aiohttp->datasets->fastbook) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\nebia\anaconda3\lib\site-packages (from aiohttp->datasets->fastbook) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\nebia\anaconda3\lib\site-packages (from aiohttp->datasets->fastbook) (4.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nebia\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets->fastbook) (4.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (6.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: psutil in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (23.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\nebia\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.36)
# Requirement already satisfied: pickleshare in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: backcall in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.11.2)
# Requirement already satisfied: decorator in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.1.1)
# Requirement already satisfied: colorama in c:\users\nebia\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.4.6)
# Requirement already satisfied: jupyter-core in c:\users\nebia\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8->fastbook) (5.2.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\nebia\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8->fastbook) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\nebia\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8->fastbook) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\nebia\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->fastbook) (1.16.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (8.1.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.8)
# Requirement already satisfied: jinja2 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (5.2.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.4.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.1.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.10.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (0.7.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.4)
# Requirement already satisfied: setuptools in c:\users\nebia\anaconda3\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (65.6.3)
# Requirement already satisfied: sympy in c:\users\nebia\anaconda3\lib\site-packages (from torch<2.1,>=1.7->fastai>=2.6->fastbook) (1.11.1)
# Requirement already satisfied: networkx in c:\users\nebia\anaconda3\lib\site-packages (from torch<2.1,>=1.7->fastai>=2.6->fastbook) (2.8.4)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\nebia\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (6.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nebia\anaconda3\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nebia\anaconda3\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nebia\anaconda3\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nebia\anaconda3\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nebia\anaconda3\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.0.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nebia\anaconda3\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\nebia\anaconda3\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\nebia\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\nebia\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8->fastbook) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\nebia\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8->fastbook) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\nebia\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8->fastbook) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nebia\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8->fastbook) (2.5.2)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\nebia\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.5.2)
# Requirement already satisfied: prometheus-client in c:\users\nebia\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\nebia\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\nebia\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\nebia\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\nebia\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.17.1)
# Requirement already satisfied: wcwidth in c:\users\nebia\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.5)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\nebia\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\nebia\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\nebia\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nebia\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.1.1)
# Requirement already satisfied: asttokens in c:\users\nebia\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\nebia\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: executing in c:\users\nebia\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nebia\anaconda3\lib\site-packages (from sympy->torch<2.1,>=1.7->fastai>=2.6->fastbook) (1.2.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\nebia\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\nebia\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.8.4)
# Requirement already satisfied: bleach in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: lxml in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (4.9.1)
# Requirement already satisfied: tinycss2 in c:\users\nebia\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.2.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\nebia\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\nebia\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\nebia\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\nebia\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\nebia\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nebia\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\nebia\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nebia\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\nebia\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastbook import*

# %% [markdown]
# #### **Download images of birds ans non-birds (forest)**

# %%
urls = search_images_ddg('bird photos', max_images=1)
len(urls), urls[0]
# Out:
# (1,
#  'https://www.almanac.com/sites/default/files/image_nodes/bluebird-3456115_1920.jpg')

# %%
dest = Path('bird.jpg')
if not dest.exists(): download_url(urls[0], dest, show_progress=False)

# %%
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x160>

# %%
urls = search_images_ddg('forest photos', max_images=1)
len(urls), urls[0]
# Out:
# (1,
#  'https://wallup.net/wp-content/uploads/2015/12/219723-nature-trees-forest-branch-sun_rays-landscape-pine_trees-sunlight-green.jpg')

# %%
dest = Path('forest.jpg')
if not dest.exists(): download_url(urls[0], dest, show_progress=False)

# %%
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x171>

# %%
searches = 'forest', 'bird'
path = Path('bird_or_not')

if not path.exists():
    path.mkdir()
    
for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True)
    results = search_images_ddg(f'{o} photo')
    download_images(dest, urls=results[:200])
    resize_images(dest, max_size=400, dest=dest)

# %% [markdown]
# #### **Training the model**

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink);

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path)

dls.show_batch(max_n=6)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.294235</td>
#       <td>0.000046</td>
#       <td>0.000000</td>
#       <td>00:56</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.008069</td>
#       <td>0.016917</td>
#       <td>0.005376</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.005265</td>
#       <td>0.000029</td>
#       <td>0.000000</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003710</td>
#       <td>0.000208</td>
#       <td>0.000000</td>
#       <td>01:16</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Testing the model to "bird.jpg" and "forest.jpg", downloaded at the start of the code**

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: bird.
# Probability it's a bird: 1.0000

# %%
is_bird,_,probs = learn.predict(PILImage.create('forest.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: forest.
# Probability it's a bird: 0.0000

# %% [markdown]
# ### 2) ------ *Segmentation* ------

# %%
path = untar_data(URLs.CAMVID_TINY)
dls = SegmentationDataLoaders.from_label_func(
    path, bs=8, fnames = get_image_files(path/"images"),
    label_func = lambda o: path/'labels'/f'{o.stem}_P{o.suffix}',
    codes = np.loadtxt(path/'codes.txt', dtype=str)
)

learn = unet_learner(dls, resnet34)
learn.fine_tune(8)
# Out:
# C:\Users\nebia\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to C:\Users\nebia/.cache\torch\hub\checkpoints\resnet34-b627a593.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 83.3M/83.3M [00:04<00:00, 20.5MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.811011</td>
#       <td>2.667720</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.230538</td>
#       <td>1.852099</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.868347</td>
#       <td>1.425735</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.634325</td>
#       <td>1.345577</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.458928</td>
#       <td>1.013040</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.321038</td>
#       <td>0.915073</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.197390</td>
#       <td>0.861751</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.088404</td>
#       <td>0.808054</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.001723</td>
#       <td>0.795141</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(max_n=3, figsize=(7,8))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ### 3) ------ *Tabular analysis /income prediction* ------

# %%
from fastai.tabular.all import *
path = untar_data(URLs.ADULT_SAMPLE)

dls = TabularDataLoaders.from_csv(path/'adult.csv', path=path, y_names="salary",
    cat_names = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race'],
    cont_names = ['age', 'fnlwgt', 'education-num'],
    procs = [Categorify, FillMissing, Normalize])

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>workclass</th>
#       <th>education</th>
#       <th>marital-status</th>
#       <th>occupation</th>
#       <th>relationship</th>
#       <th>race</th>
#       <th>education-num_na</th>
#       <th>age</th>
#       <th>fnlwgt</th>
#       <th>education-num</th>
#       <th>salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Local-gov</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Protective-serv</td>
#       <td>Other-relative</td>
#       <td>White</td>
#       <td>False</td>
#       <td>22.000000</td>
#       <td>195531.999848</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Private</td>
#       <td>Bachelors</td>
#       <td>Never-married</td>
#       <td>Prof-specialty</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>33.000000</td>
#       <td>191384.999915</td>
#       <td>13.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Private</td>
#       <td>7th-8th</td>
#       <td>Married-civ-spouse</td>
#       <td>Machine-op-inspct</td>
#       <td>Wife</td>
#       <td>Other</td>
#       <td>False</td>
#       <td>47.000000</td>
#       <td>103020.000400</td>
#       <td>4.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Self-emp-not-inc</td>
#       <td>HS-grad</td>
#       <td>Married-civ-spouse</td>
#       <td>Transport-moving</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>42.000000</td>
#       <td>238188.000476</td>
#       <td>9.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Married-spouse-absent</td>
#       <td>Adm-clerical</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>52.000000</td>
#       <td>218550.001411</td>
#       <td>10.0</td>
#       <td>&gt;=50k</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Self-emp-not-inc</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Craft-repair</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>40.000000</td>
#       <td>165815.000332</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Private</td>
#       <td>1st-4th</td>
#       <td>Never-married</td>
#       <td>Handlers-cleaners</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>31.000000</td>
#       <td>248652.999275</td>
#       <td>2.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Private</td>
#       <td>Bachelors</td>
#       <td>Married-civ-spouse</td>
#       <td>Tech-support</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>45.000000</td>
#       <td>275994.997272</td>
#       <td>13.0</td>
#       <td>&gt;=50k</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>State-gov</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Prof-specialty</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>20.000000</td>
#       <td>243986.002229</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Never-married</td>
#       <td>Exec-managerial</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>23.000001</td>
#       <td>320293.995233</td>
#       <td>9.0</td>
#       <td>&lt;50k</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = tabular_learner(dls, metrics=accuracy)
learn.fit_one_cycle(2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.372341</td>
#       <td>0.368513</td>
#       <td>0.832310</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.355164</td>
#       <td>0.360277</td>
#       <td>0.830927</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4) ------ *collaborative filtering - recommendation system* ------

# %%
from fastai.collab import*
path = untar_data(URLs.ML_SAMPLE)
dls = CollabDataLoaders.from_csv(path/'ratings.csv')

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>605</td>
#       <td>587</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>452</td>
#       <td>780</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>430</td>
#       <td>539</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>299</td>
#       <td>592</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>452</td>
#       <td>1923</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>346</td>
#       <td>260</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>423</td>
#       <td>1097</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>306</td>
#       <td>1210</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>544</td>
#       <td>1240</td>
#       <td>4.5</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>294</td>
#       <td>39</td>
#       <td>4.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = collab_learner(dls, y_range=(0.5, 5.5))
learn.fine_tune(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.516658</td>
#       <td>1.434386</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.361568</td>
#       <td>1.376410</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.264634</td>
#       <td>1.203035</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.030925</td>
#       <td>0.904237</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.814036</td>
#       <td>0.756642</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.692789</td>
#       <td>0.718271</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.636861</td>
#       <td>0.704253</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.613095</td>
#       <td>0.698143</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.605075</td>
#       <td>0.696585</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.600052</td>
#       <td>0.695358</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.594405</td>
#       <td>0.695221</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#       <th>rating_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>66.0</td>
#       <td>55.0</td>
#       <td>5.0</td>
#       <td>4.519696</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11.0</td>
#       <td>22.0</td>
#       <td>4.0</td>
#       <td>3.401010</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15.0</td>
#       <td>38.0</td>
#       <td>4.0</td>
#       <td>4.354965</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.0</td>
#       <td>78.0</td>
#       <td>4.0</td>
#       <td>3.249570</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>28.0</td>
#       <td>80.0</td>
#       <td>2.5</td>
#       <td>3.136662</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>98.0</td>
#       <td>68.0</td>
#       <td>4.5</td>
#       <td>4.075378</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>66.0</td>
#       <td>72.0</td>
#       <td>4.0</td>
#       <td>3.254244</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>42.0</td>
#       <td>26.0</td>
#       <td>4.5</td>
#       <td>3.681634</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>59.0</td>
#       <td>41.0</td>
#       <td>4.0</td>
#       <td>4.546864</td>
#     </tr>
#   </tbody>
# </table>
